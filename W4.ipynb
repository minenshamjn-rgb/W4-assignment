# %%
inventory = {
    "rice":  {"price": 120, "stock": 20},
    "milk":  {"price": 90,  "stock": 10},
    "bread": {"price": 60,  "stock": 15},
    "eggs":  {"price": 15,  "stock": 30}
}

cart = {
    "rice": 2,
    "milk": 3,
    "eggs": 12
}

def process_order(inventory, cart):
    total = 0
    bill_items = {}

    for item in cart:
        qty = cart[item]
        if item in inventory:
            if inventory[item]["stock"] >= qty:
                cost = inventory[item]["price"] * qty
                bill_items[item] = (qty, cost)
                inventory[item]["stock"] -= qty
                total += cost
            else:
                print(f"Sorry, not enough stock for {item}")

    print("\n---- Bill ----")
    for item in bill_items:
        qty, cost = bill_items[item]
        print(f"{item} x{qty} = NPR {cost}")
    print(f"Grand Total: NPR {total}")
    print("--------------")

    print("\nUpdated stock:", end=" ")
    stock_info = []
    for item in inventory:
        stock_info.append(f"{item}={inventory[item]['stock']}")
    print(", ".join(stock_info))

process_order(inventory, cart)
# Out:
# ---- Bill ----
# rice x2 = NPR 240
# milk x3 = NPR 270
# eggs x12 = NPR 180
# Grand Total: NPR 690
# --------------
#
# Updated stock: rice=18, milk=7, bread=15, eggs=18

# %%
sensors = [
    ("Chatara", 2.8),
    ("Tribeni Ghat", 5.4),
    ("Koshi Barrage", 4.1),
    ("Sunsari Bridge", 1.9),
    ("Saptakoshi Camp", 6.0),
]

def check_water_level(location, level_metres):
    if level_metres < 3:
        return "Safe"
    elif level_metres <= 5:
        return "Warning — Alert nearby villages"
    else:
        return "DANGER — Evacuate immediately!"

for location, level in sensors:
    result = check_water_level(location, level)
    print(f"{location} ({level} m): {result}")
# Out:
# Chatara (2.8 m): Safe
# Tribeni Ghat (5.4 m): DANGER — Evacuate immediately!
# Koshi Barrage (4.1 m): Warning — Alert nearby villages
# Sunsari Bridge (1.9 m): Safe
# Saptakoshi Camp (6.0 m): DANGER — Evacuate immediately!

# %%
bs_months = ["Baisakh","Jestha","Ashadh","Shrawan","Bhadra","Ashwin",
             "Kartik","Mangsir","Poush","Magh","Falgun","Chaitra"]

customers = [
    {"name": "Ramesh Thapa", "date": "1985-06-24", "cal": "AD", "need": "BS", "style": "full"},
    {"name": "Sunita Karki", "date": "2055-09-10", "cal": "BS", "need": "AD", "style": "iso"},
    {"name": "Bikash Rai", "date": "1998-11-30", "cal": "AD", "need": "BS", "style": "nepali"},
    {"name": "Anjali Gurung", "date": "2040-01-05", "cal": "BS", "need": "AD", "style": "full"},
]

def convert_date(date_str, from_cal, to_cal):
    parts = date_str.split("-")
    year = int(parts[0])
    month = int(parts[1])
    day = int(parts[2])

    if from_cal == to_cal:
        return date_str

    if from_cal == "AD" and to_cal == "BS":
        year = year + 56
    elif from_cal == "BS" and to_cal == "AD":
        year = year - 56

    return f"{year}-{str(month).zfill(2)}-{str(day).zfill(2)}"

for c in customers:
    converted = convert_date(c["date"], c["cal"], c["need"])
    parts = converted.split("-")
    year = int(parts[0])
    month = int(parts[1])
    day = int(parts[2])

    if c["style"] == "iso":
        formatted = converted
    elif c["style"] == "full":
        month_name = bs_months[month - 1]
        formatted = f"{day}th {month_name}, {year} {c['need']}"
    elif c["style"] == "nepali":
        month_name = bs_months[month - 1]
        formatted = f"{day} {month_name} {year}"

    print(f"{c['name']} | Original: {c['date']} {c['cal']} | Converted: {formatted}")
# Out:
# Ramesh Thapa | Original: 1985-06-24 AD | Converted: 24th Ashwin, 2041 BS
# Sunita Karki | Original: 2055-09-10 BS | Converted: 1999-09-10
# Bikash Rai | Original: 1998-11-30 AD | Converted: 30 Falgun 2054
# Anjali Gurung | Original: 2040-01-05 BS | Converted: 5th Baisakh, 1984 AD

# %%
text = """
Nepal is a beautiful country. Nepal has Mount Everest.
Everest is the highest mountain in the world. Many tourists
visit Nepal every year to see Everest and other mountains.
Nepal is known for its mountains and natural beauty.
"""

def word_frequency(text):
    text = text.replace(".", "").replace(",", "")
    words = text.lower().split()

    counts = {}
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    sorted_words = sorted(counts, key=lambda w: counts[w], reverse=True)

    print("Top 3 words:")
    for i in range(3):
        word = sorted_words[i]
        print(f"{word} — {counts[word]} times")

word_frequency(text)
# Out:
# Top 3 words:
# nepal — 4 times
# is — 3 times
# everest — 3 times

# %%
accounts = {
    "A001": {"name": "Ramesh Thapa",  "balance": 15000, "pin": "1234"},
    "A002": {"name": "Sunita Karki",  "balance": 8500,  "pin": "5678"},
    "A003": {"name": "Bikash Rai",    "balance": 22000, "pin": "9012"}
}

def atm(account_id, pin, action, amount=0):
    if account_id not in accounts:
        print("Account not found")
        return

    account = accounts[account_id]

    if account["pin"] != pin:
        print("Incorrect PIN")
        return

    if action == "balance":
        print(f"{account['name']}'s balance: NPR {account['balance']}")

    elif action == "deposit":
        account["balance"] += amount
        print(f"Deposited NPR {amount}. New balance: NPR {account['balance']}")

    elif action == "withdraw":
        if amount > account["balance"]:
            print("Insufficient funds")
        else:
            account["balance"] -= amount
            print(f"Withdrew NPR {amount}. New balance: NPR {account['balance']}")

atm("A001", "1234", "balance")
atm("A002", "0000", "withdraw", 2000)   # wrong PIN
atm("A002", "5678", "deposit", 3000)
atm("A003", "9012", "withdraw", 25000)  # insufficient funds
atm("A004", "1111", "balance")          # account not found
# Out:
# Ramesh Thapa's balance: NPR 15000
# Incorrect PIN
# Deposited NPR 3000. New balance: NPR 11500
# Insufficient funds
# Account not found
